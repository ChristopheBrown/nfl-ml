# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF
import nfl_data_py as nfl

pd.set_option("display.max_columns", None)

# %%
def player_id_to_int(player_id):
#     print(player_id)
    return int(player_id[3:])

def save_player_id_map(df, path='csv/player_id_map.csv'):
    df.to_csv(path)
    
def prep_players(df):
    
    #  Extract lists of all unique passers and receivers (as well as their IDs)
    receiver_dict = dict(list(df.groupby(['receiver_player_id','receiver_player_name']).groups.keys()))
    receiver_ids, receiver_names = list(receiver_dict.keys()), list(receiver_dict.values())

    passer_dict = dict(list(df.groupby(['passer_player_id','passer_player_name']).groups.keys()))
    passer_ids, passer_names = list(passer_dict.keys()), list(passer_dict.values())

    #  Lists of receiver and passers can be combined into a list of all players with their IDs
    receivers = {
        'player_id': receiver_ids,
        'player_name': receiver_names
    }

    passers = {
        'player_id': passer_ids,
        'player_name': passer_names
    }

    passer_df = pd.DataFrame.from_dict(passers)
    receiver_df = pd.DataFrame.from_dict(receivers)

    #  This dataframe allows you to get a players name, give their ID, we can save this separately
    player_id_index = pd.concat([passer_df,receiver_df])  # save this to its own CSV file
    save_player_id_map(player_id_index)
    
    return passer_df, receiver_df, player_id_index

def prep_X(df, receiver_df, passer_df):
    
    #  The number of receivers and passers make up the dimensions of X
    rec_ct = receiver_df.shape[0]
    pass_ct = passer_df.shape[0]

    X = np.zeros((rec_ct,pass_ct))

    #  Iterate over the rows of our main dataframe to tally the passing yards for complete pass plays
    #  "For every completed play, get receiver index and passer index and -> X[receiver_idx][passer_idx] += gain"
    for row in df.itertuples(index=False):
        if row.play_type_nfl=='PASS' and not row.interception and not row.qb_spike and not row.incomplete_pass:
            gain = row.receiving_yards

            rec_id = row.receiver_player_id
            receiver_idx = receiver_df.index[receiver_df['player_id'] == rec_id].tolist()[0]

            pass_id = row.passer_player_id
            passer_idx = passer_df.index[passer_df['player_id'] == pass_id].tolist()[0]

    #         print(f'{passer_df.iloc[passer_idx].player_name} to  {receiver_df.iloc[receiver_idx].player_name} for {gain} yards')

            X[receiver_idx][passer_idx] += gain
    return X

def normalize_rows(W_T): # accepts W.T as a parameter
    W_T_norm = np.zeros_like(W_T)
    
    for row in range(W_T.shape[0]):
        row_sum = np.sum(W_T[row])
        W_T_norm[row] = W_T[row] / row_sum
        
    return W_T_norm

def normalize_columns(H_T): # accepts H.T as a parameter
    H_T_norm = np.zeros_like(H_T)
    
    for col in range(H_T.shape[1]):
        col_sum = np.sum(H_T[:,col])
        H_T_norm[:,col] = H_T[:,col] / col_sum
        
    return H_T_norm

def fetch_receiver(index, player_id_index):
    return player_id_index.iloc[index]['player_name']

# %%
relevant_columns = [
    'game_id',
    'posteam',
    'pass', # 1
    'play_type_nfl', # PASS
    'incomplete_pass', # 0
    'success', # 1
    'receiving_yards',
    'passer_player_name',
    'receiver_player_name',
    'passer_player_id',
    'receiver_player_id',
    'interception',
    'qb_spike',
    'passer',
    'rusher',
    'receiver',
    'air_yards',
    'desc'
]

nfl_qbs = [
    "C.McCoy",
    "M.Ryan",
    "L.Jackson",
    "Jos.Allen",
    "P.Walker",
    "J.Fields",
    "J.Burrow",
    "B.Mayfield",
    "D.Prescott",
    "T.Bridgewater",
    "J.Goff",
    "Aa.Rodgers",
    "Ty.Taylor",
    "C.Wentz",
    "T.Lawrence",
    "P.Mahomes",
    "D.Carr",
    "J.Herbert",
    "M.Stafford",
    "J.Brissett",
    "K.Cousins",
    "M.Jones",
    "T.Siemian",
    "D.Jones",
    "M.White",
    "J.Hurts",
    "M.Rudolph",
    "J.Garoppolo",
    "R.Wilson",
    "T.Brady",
    "R.Tannehill",
    "T.Heinicke",
    "B"
]

# %%
time_period = list(range(2010,2021+1))

nfl_season_pbp = nfl.import_pbp_data(time_period)[relevant_columns]
nfl_season_pbp = nfl_season_pbp.loc[nfl_season_pbp['play_type_nfl'] == 'PASS']
nfl_season_pbp = nfl_season_pbp.loc[pd.notna(nfl_season_pbp['receiver_player_id'])]
# Out:
# 2010 done.
# 2011 done.
# 2012 done.
# 2013 done.
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# Downcasting floats.

# %%
passer_df, receiver_df, player_id_index = prep_players(nfl_season_pbp)
X = prep_X(nfl_season_pbp, receiver_df, passer_df)

# NMF must be non-negative! We will treat net-negative yardage as zero-gain
X[X<0] = 0

X.shape
# Out:
# (1857, 398)

# %%
k_ranks = np.arange(3,15)  # The number of "receiver groups" to learn
tolerance = 0.01 # Stopping condition for training. Smaller value = more training

alpha = 0
alpha_W = alpha # regularization parameter for W
alpha_H = alpha # regularization parameter for H
avg_qb_scores = []


for k in k_ranks:
    
    print(f'K = {k}')

    model = NMF(n_components=k, init='random', tol=tolerance, 
                random_state=0, 
                alpha_W=alpha_W, 
                alpha_H=alpha_H)

    W = model.fit_transform(X)
    H = model.components_

    # --------------------------------------------------------------------------------

    # creating the dataframe
    df_X = pd.DataFrame(data = X, 
                      index = list(receiver_df.player_name), 
                      columns = list(passer_df.player_name))
    # df_X

    # normalizing our learned matrices for analysis

    H_row_sum = np.sum(H, axis=0).reshape(1,-1)
    H_norm = np.divide(H, H_row_sum, out=np.zeros_like(H), where=H_row_sum!=0)

    df_H = pd.DataFrame(data = H_norm, 
                      index = [f'rec_group_{n}' for n in range(H_norm.shape[0])], 
                      columns = list(passer_df.player_name))
    # df_H


    W_col_sum = np.sum(W, axis=1).reshape(-1,1)
    W_norm = np.divide(W, W_col_sum, out=np.zeros_like(W), where=W_col_sum!=0)


    df_W = pd.DataFrame(data = W_norm, 
                      index = list(receiver_df.player_name), 
                      columns = [f'rec_group_{n}' for n in range(W_norm.shape[1])])
    # df_W

    # --------------------------------------------------------------------------------

    group_qb_scores = []
    
    for group in range(k):
        
        
        print(f'GROUP {group+1} out of {k} k-rank group(s)')

        qb_rankings = df_H.loc[f'rec_group_{group}'].where(df_H.loc[f'rec_group_{group}'] > .5).dropna()

        avg_qb_score = 0 

        for qb in qb_rankings.index:
            if (qb in nfl_qbs):
                avg_qb_score += qb_rankings.loc[qb]
    #             print(f'{qb}: {qb_rankings.loc[qb]}')

        avg_qb_score /= len(nfl_qbs)
        group_qb_scores.append(avg_qb_score)

        print(f'average quarterback score: {avg_qb_score}')
        
        print('-------------------------------------\n')
        # All quarterbacks are ranked (qb_rankings), this line takes only those starting in the 2021 season (nfl_qbs)
        print(f'Quarterbacks{list(set(qb_rankings.index) & set(nfl_qbs))}')
        print('\n')
        print(f'Receivers: {list(df_W.nlargest(10,f"rec_group_{group}").iloc[:10].T.columns)}')
    #     display(df_W.nlargest(25,f'rec_group_{group}').iloc[:25].T)
        print('\n\n')
        
    avg_qb_scores.append(np.mean(group_qb_scores))

    print('\n--------------------------------------------------------------------------------\n')
# Out:
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2337441615971024
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.35409851552807786
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Goff', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07181846311613063
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 4
# GROUP 1 out of 4 k-rank group(s)
# average quarterback score: 0.13303705056189907
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'T.Bridgewater', 'D.Carr', 'Aa.Rodgers', 'L.Jackson']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 2 out of 4 k-rank group(s)
# average quarterback score: 0.26848633514777903
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Stafford', 'T.Lawrence', 'C.Wentz', 'R.Wilson', 'K.Cousins', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Mahomes', 'M.White', 'J.Hurts']
#
#
# Receivers: ['M.Morris', 'W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'K.Ogletree', 'B.Pettigrew', 'B.Robiskie']
#
#
#
# GROUP 3 out of 4 k-rank group(s)
# average quarterback score: 0.050409292703694694
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'G.Johnson', 'M.Johnson']
#
#
#
# GROUP 4 out of 4 k-rank group(s)
# average quarterback score: 0.20766350135099426
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'D.Carr', 'J.Brissett', 'T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'A.Randle El', 'D.Branch', 'H.Miller', 'M.Slater', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 5
# GROUP 1 out of 5 k-rank group(s)
# average quarterback score: 0.10280560715938596
# -------------------------------------
#
# Quarterbacks['J.Herbert', 'T.Bridgewater', 'C.McCoy', 'L.Jackson', 'J.Fields']
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Sproles', 'D.Thomas', 'M.Colston']
#
#
#
# GROUP 2 out of 5 k-rank group(s)
# average quarterback score: 0.07398900761924945
# -------------------------------------
#
# Quarterbacks['D.Carr', 'D.Prescott', 'Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree', 'D.Nance']
#
#
#
# GROUP 3 out of 5 k-rank group(s)
# average quarterback score: 0.04856831211982123
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'G.Johnson', 'M.Johnson']
#
#
#
# GROUP 4 out of 5 k-rank group(s)
# average quarterback score: 0.14645739036980887
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'M.Jones', 'J.Garoppolo', 'D.Carr', 'M.Rudolph', 'T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'A.Randle El', 'D.Branch', 'H.Miller', 'M.Slater', 'I.Redman']
#
#
#
# GROUP 5 out of 5 k-rank group(s)
# average quarterback score: 0.21848319437329353
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Stafford', 'T.Lawrence', 'R.Wilson', 'K.Cousins', 'T.Heinicke', 'J.Burrow', 'P.Mahomes', 'M.White', 'D.Jones']
#
#
# Receivers: ['M.Morris', 'W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'R.Mundy', 'S.Logan', 'C.Daniel', 'B.Pettigrew']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 6
# GROUP 1 out of 6 k-rank group(s)
# average quarterback score: 0.04270611233336476
# -------------------------------------
#
# Quarterbacks['C.McCoy', 'L.Jackson']
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 6 k-rank group(s)
# average quarterback score: 0.03029993686616008
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['Z.Miller', 'C.Martin', 'W.Tukuafu', 'D.Baldwin', 'R.Lockette', 'C.Matthews', 'C.Helfet', 'B.Daniels', 'K.Smith', 'K.Norwood']
#
#
#
# GROUP 3 out of 6 k-rank group(s)
# average quarterback score: 0.04703398554436013
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'G.Johnson', 'M.Johnson']
#
#
#
# GROUP 4 out of 6 k-rank group(s)
# average quarterback score: 0.14022285820610972
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'M.Jones', 'J.Garoppolo', 'D.Carr', 'M.Rudolph', 'T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'A.Randle El', 'D.Branch', 'H.Miller', 'M.Slater', 'I.Redman']
#
#
#
# GROUP 5 out of 6 k-rank group(s)
# average quarterback score: 0.18665062675588798
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Stafford', 'T.Lawrence', 'K.Cousins', 'J.Burrow', 'P.Mahomes', 'M.White', 'D.Jones']
#
#
# Receivers: ['M.Morris', 'W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'B.Pettigrew', 'A.Brown', 'K.Williams']
#
#
#
# GROUP 6 out of 6 k-rank group(s)
# average quarterback score: 0.08117215082471968
# -------------------------------------
#
# Quarterbacks['D.Carr', 'D.Prescott', 'Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'B.Jackson', 'K.Hall', 'J.Nelson', 'J.Finley', 'R.Mundy', 'C.Daniel', 'T.Crabtree', 'J.Starks', 'A.Green']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 7
# GROUP 1 out of 7 k-rank group(s)
# average quarterback score: 0.02490184673622042
# -------------------------------------
#
# Quarterbacks['L.Jackson']
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 7 k-rank group(s)
# average quarterback score: 0.048364634964823225
# -------------------------------------
#
# Quarterbacks['R.Wilson', 'J.Herbert']
#
#
# Receivers: ['Z.Miller', 'C.Martin', 'W.Tukuafu', 'D.Baldwin', 'R.Lockette', 'C.Matthews', 'C.Helfet', 'B.Daniels', 'K.Smith', 'K.Norwood']
#
#
#
# GROUP 3 out of 7 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'G.Johnson', 'M.Johnson']
#
#
#
# GROUP 4 out of 7 k-rank group(s)
# average quarterback score: 0.07017097246635551
# -------------------------------------
#
# Quarterbacks['D.Carr', 'M.Jones', 'T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez', 'J.Develin']
#
#
#
# GROUP 5 out of 7 k-rank group(s)
# average quarterback score: 0.13094266018089384
# -------------------------------------
#
# Quarterbacks['J.Goff', 'T.Lawrence', 'J.Burrow', 'M.Stafford', 'D.Jones']
#
#
# Receivers: ['M.Morris', 'W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'B.Pettigrew', 'K.Williams', 'J.Bell']
#
#
#
# GROUP 6 out of 7 k-rank group(s)
# average quarterback score: 0.07772292452514848
# -------------------------------------
#
# Quarterbacks['D.Carr', 'D.Prescott', 'Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'B.Jackson', 'K.Hall', 'J.Nelson', 'J.Finley', 'T.Crabtree', 'A.Quarless', 'J.Starks', 'A.Green']
#
#
#
# GROUP 7 out of 7 k-rank group(s)
# average quarterback score: 0.16764472217103535
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'J.Garoppolo', 'M.Rudolph', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'R.Mundy', 'C.Daniel', 'I.Redman', 'D.Johnson', 'C.McCoy', 'J.Dwyer', 'C.Chekwa']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 8
# GROUP 1 out of 8 k-rank group(s)
# average quarterback score: 0.024965091365257763
# -------------------------------------
#
# Quarterbacks['L.Jackson']
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 8 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 8 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'JulioJones']
#
#
#
# GROUP 4 out of 8 k-rank group(s)
# average quarterback score: 0.030271898672965727
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez', 'J.Develin']
#
#
#
# GROUP 5 out of 8 k-rank group(s)
# average quarterback score: 0.10170005520296276
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford', 'J.Goff', 'D.Jones']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'B.Pettigrew', 'K.Williams', 'J.Bell', 'T.Young']
#
#
#
# GROUP 6 out of 8 k-rank group(s)
# average quarterback score: 0.09913720836945412
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'J.Burrow', 'J.Herbert', 'M.Jones']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'K.Wilson', 'P.Crayton', 'R.Brown', 'C.Davis', 'G.Banks', 'C.Brinkley']
#
#
#
# GROUP 7 out of 8 k-rank group(s)
# average quarterback score: 0.13443653332264707
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'J.Garoppolo', 'M.Rudolph', 'J.Fields', 'R.Tannehill']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'I.Redman', 'J.Dwyer', 'B.Batch', 'Wi.Johnson', 'D.Moye', 'C.Rainey', 'D.Paulson']
#
#
#
# GROUP 8 out of 8 k-rank group(s)
# average quarterback score: 0.0666754681621309
# -------------------------------------
#
# Quarterbacks['D.Carr', 'D.Prescott', 'Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'R.Mundy', 'C.Daniel', 'T.Crabtree', 'C.McCoy', 'J.Starks', 'A.Green', 'C.Chekwa']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 9
# GROUP 1 out of 9 k-rank group(s)
# average quarterback score: 0.023358471832532236
# -------------------------------------
#
# Quarterbacks['L.Jackson']
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 9 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 9 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'JulioJones']
#
#
#
# GROUP 4 out of 9 k-rank group(s)
# average quarterback score: 0.030251929945526484
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez', 'J.Develin']
#
#
#
# GROUP 5 out of 9 k-rank group(s)
# average quarterback score: 0.09143744854775374
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford', 'J.Goff', 'D.Jones']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'B.Pettigrew', 'J.Bell', 'T.Young', 'M.Leshoure']
#
#
#
# GROUP 6 out of 9 k-rank group(s)
# average quarterback score: 0.0481721803205437
# -------------------------------------
#
# Quarterbacks['J.Burrow', 'D.Prescott']
#
#
# Receivers: ['C.Pressley', 'C.Peerman', 'A.Green', 'R.Whalen', 'C.Cochart', 'T.Eifert', 'R.Hewitt', 'J.Wright', 'J.Fisher', 'T.Boyd']
#
#
#
# GROUP 7 out of 9 k-rank group(s)
# average quarterback score: 0.13306325720292153
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'J.Garoppolo', 'M.Rudolph', 'P.Mahomes', 'R.Tannehill']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'I.Redman', 'B.Batch', 'Wi.Johnson', 'D.Moye', 'C.Rainey', 'D.Paulson', 'C.Hamilton']
#
#
#
# GROUP 8 out of 9 k-rank group(s)
# average quarterback score: 0.030302561670874115
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'A.Green', 'D.Williams', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis']
#
#
#
# GROUP 9 out of 9 k-rank group(s)
# average quarterback score: 0.06927063018963132
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'J.Herbert', 'M.Jones']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'K.Wilson', 'P.Crayton', 'C.Davis', 'G.Banks', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 10
# GROUP 1 out of 10 k-rank group(s)
# average quarterback score: 0.0
# -------------------------------------
#
# Quarterbacks[]
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 10 k-rank group(s)
# average quarterback score: 0.030301218503318864
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 10 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'JulioJones']
#
#
#
# GROUP 4 out of 10 k-rank group(s)
# average quarterback score: 0.030279572714905834
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'A.Crumpler', 'D.Branch', 'M.Slater', 'R.Gronkowski', 'A.Hernandez', 'J.Develin', 'N.Solder', 'M.Williams']
#
#
#
# GROUP 5 out of 10 k-rank group(s)
# average quarterback score: 0.06913558102116528
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford', 'J.Goff']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'C.Johnson', 'S.Logan', 'J.Bell', 'T.Young', 'M.Leshoure', 'R.Broyles', 'P.Edwards', 'J.Fauria']
#
#
#
# GROUP 6 out of 10 k-rank group(s)
# average quarterback score: 0.06946706156984742
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'J.Burrow', 'D.Prescott']
#
#
# Receivers: ['T.Irwin', 'D.Sample', 'T.Higgins', 'C.Evans', 'J.Chase', 'O.Beckham Jr.', 'P.Perkins', 'A.Robinson', 'D.Scott', 'J.Jernigan']
#
#
#
# GROUP 7 out of 10 k-rank group(s)
# average quarterback score: 0.3163275255230324
# -------------------------------------
#
# Quarterbacks['M.Jones', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'Ty.Taylor', 'D.Carr', 'L.Jackson', 'K.Cousins', 'T.Heinicke', 'P.Walker', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['C.Williams', 'C.McCaffrey', 'B.Bersin', 'C.Brown', 'B.Hartsock', 'D.Reaves', 'C.Artis-Payne', 'K.Pilares', 'J.Adams', 'R.Brockel']
#
#
#
# GROUP 8 out of 10 k-rank group(s)
# average quarterback score: 0.030302096576917847
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'D.Williams', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis', 'D.Adams']
#
#
#
# GROUP 9 out of 10 k-rank group(s)
# average quarterback score: 0.04726818195629609
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'J.Herbert']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'P.Crayton', 'C.Davis', 'G.Banks', 'C.Brinkley', 'R.Goodman', 'K.Allen']
#
#
#
# GROUP 10 out of 10 k-rank group(s)
# average quarterback score: 0.048245542193359414
# -------------------------------------
#
# Quarterbacks['M.Rudolph', 'T.Siemian']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'R.Mundy', 'C.Daniel', 'I.Redman', 'C.McCoy', 'C.Chekwa', 'B.Batch', 'Wi.Johnson']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 11
# GROUP 1 out of 11 k-rank group(s)
# average quarterback score: 0.0
# -------------------------------------
#
# Quarterbacks[]
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'C.Roby', 'D.Thomas', 'M.Colston', 'P.Thomas']
#
#
#
# GROUP 2 out of 11 k-rank group(s)
# average quarterback score: 0.030299667180490094
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 11 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'JulioJones']
#
#
#
# GROUP 4 out of 11 k-rank group(s)
# average quarterback score: 0.03028301526088197
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'A.Crumpler', 'M.Slater', 'R.Gronkowski', 'A.Hernandez', 'J.Develin', 'N.Solder', 'M.Williams', 'J.Boyce']
#
#
#
# GROUP 5 out of 11 k-rank group(s)
# average quarterback score: 0.0872865463617054
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford', 'J.Goff', 'D.Jones']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'T.Scheffler', 'C.Johnson', 'K.Smith', 'S.Logan', 'B.Pettigrew', 'J.Bell', 'T.Young', 'M.Leshoure']
#
#
#
# GROUP 6 out of 11 k-rank group(s)
# average quarterback score: 0.10164303287811627
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'D.Carr', 'K.Cousins']
#
#
# Receivers: ['J.Witten', 'M.Austin', 'L.Vickers', 'J.Holley', 'C.Washington', 'M.Johnson', 'D.Bryant', 'P.Tanner', 'L.Dunbar', 'J.Hanna']
#
#
#
# GROUP 7 out of 11 k-rank group(s)
# average quarterback score: 0.19105854489409324
# -------------------------------------
#
# Quarterbacks['M.Jones', 'C.Wentz', 'T.Bridgewater', 'D.Carr', 'L.Jackson', 'T.Heinicke', 'P.Walker', 'P.Mahomes', 'M.White', 'J.Hurts']
#
#
# Receivers: ['B.Hartsock', 'C.Williams', 'R.Brockel', 'K.Pilares', 'J.Adams', 'B.Bersin', 'C.Brown', 'D.Reaves', 'C.Artis-Payne', 'D.Funchess']
#
#
#
# GROUP 8 out of 11 k-rank group(s)
# average quarterback score: 0.030301809056179328
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis', 'D.Adams', 'A.Ripkowski']
#
#
#
# GROUP 9 out of 11 k-rank group(s)
# average quarterback score: 0.04629280557061146
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'J.Herbert']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'P.Crayton', 'C.Davis', 'G.Banks', 'C.Brinkley', 'R.Goodman', 'K.Allen']
#
#
#
# GROUP 10 out of 11 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['J.Burrow']
#
#
# Receivers: ['C.Peerman', 'A.Green', 'R.Whalen', 'C.Cochart', 'T.Eifert', 'R.Hewitt', 'J.Wright', 'C.Uzomah', 'J.Fisher', 'A.Erickson']
#
#
#
# GROUP 11 out of 11 k-rank group(s)
# average quarterback score: 0.030115035142789848
# -------------------------------------
#
# Quarterbacks['M.Rudolph']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'R.Mundy', 'C.Daniel', 'I.Redman', 'C.McCoy', 'C.Chekwa', 'B.Batch', 'Wi.Johnson']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 12
# GROUP 1 out of 12 k-rank group(s)
# average quarterback score: 0.0
# -------------------------------------
#
# Quarterbacks[]
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'D.Thomas', 'M.Colston', 'A.Arrington', 'M.Ingram II']
#
#
#
# GROUP 2 out of 12 k-rank group(s)
# average quarterback score: 0.030299615169348506
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 12 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'Dr.Davis']
#
#
#
# GROUP 4 out of 12 k-rank group(s)
# average quarterback score: 0.0954807711662615
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'T.Siemian', 'P.Mahomes', 'K.Cousins']
#
#
# Receivers: ['R.Wayne', 'D.Carter', 'J.Robinson', 'S.Havili', 'D.Rogers', 'D.Herron', 'L.Brazill', 'A.Castonzo', 'K.Adams', 'V.Ballard']
#
#
#
# GROUP 5 out of 12 k-rank group(s)
# average quarterback score: 0.06303867943517293
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford', 'J.Goff']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'C.Johnson', 'S.Logan', 'J.Bell', 'T.Young', 'M.Leshoure', 'R.Broyles', 'P.Edwards', 'J.Fauria']
#
#
#
# GROUP 6 out of 12 k-rank group(s)
# average quarterback score: 0.04313261776063879
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'D.Jones']
#
#
# Receivers: ['M.Clayton', 'B.Jacobs', 'M.Hedgecock', 'D.Thomas', 'R.Barden', 'T.Beckum', 'A.Brown', 'R.Jennings', 'J.Ballard', 'D.Calhoun']
#
#
#
# GROUP 7 out of 12 k-rank group(s)
# average quarterback score: 0.14440458934956865
# -------------------------------------
#
# Quarterbacks['M.Jones', 'C.Wentz', 'T.Bridgewater', 'L.Jackson', 'T.Heinicke', 'P.Walker', 'J.Hurts']
#
#
# Receivers: ['C.Williams', 'C.McCaffrey', 'B.Bersin', 'C.Brown', 'C.Artis-Payne', 'B.Hartsock', 'D.Reaves', 'J.Adams', 'D.Keene', 'R.Brockel']
#
#
#
# GROUP 8 out of 12 k-rank group(s)
# average quarterback score: 0.03030192429288109
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'D.Williams', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis', 'D.Adams']
#
#
#
# GROUP 9 out of 12 k-rank group(s)
# average quarterback score: 0.029897720320791618
# -------------------------------------
#
# Quarterbacks['J.Herbert']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'P.Crayton', 'C.Davis', 'G.Banks', 'C.Brinkley', 'R.Goodman', 'K.Allen']
#
#
#
# GROUP 10 out of 12 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['J.Burrow']
#
#
# Receivers: ['A.Green', 'R.Whalen', 'C.Cochart', 'J.Wright', 'J.Fisher', 'T.Boyd', 'J.Mixon', 'J.Franks', 'A.Tate', 'T.Irwin']
#
#
#
# GROUP 11 out of 12 k-rank group(s)
# average quarterback score: 0.03011791849403734
# -------------------------------------
#
# Quarterbacks['M.Rudolph']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'I.Redman', 'B.Batch', 'Wi.Johnson', 'D.Moye', 'C.Rainey', 'D.Paulson', 'C.Hamilton']
#
#
#
# GROUP 12 out of 12 k-rank group(s)
# average quarterback score: 0.030277258634478953
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'A.Crumpler', 'M.Slater', 'C.Daniel', 'R.Gronkowski', 'C.McCoy', 'A.Hernandez', 'N.Solder', 'C.Chekwa']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 13
# GROUP 1 out of 13 k-rank group(s)
# average quarterback score: 0.0
# -------------------------------------
#
# Quarterbacks[]
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'D.Thomas', 'M.Colston', 'A.Arrington', 'M.Higgins']
#
#
#
# GROUP 2 out of 13 k-rank group(s)
# average quarterback score: 0.03029921855257765
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 13 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'Dr.Davis']
#
#
#
# GROUP 4 out of 13 k-rank group(s)
# average quarterback score: 0.04971342193038441
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'T.Siemian']
#
#
# Receivers: ['R.Wayne', 'R.Quinn', 'D.Epps', 'J.Johnson', 'L.Brazill', 'V.Ballard', 'T.Varga', 'A.Castonzo', 'K.Adams', 'J.Cunningham']
#
#
#
# GROUP 5 out of 13 k-rank group(s)
# average quarterback score: 0.04592441921324598
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'C.Johnson', 'S.Logan', 'J.Bell', 'T.Young', 'M.Leshoure', 'R.Broyles', 'P.Edwards', 'J.Fauria']
#
#
#
# GROUP 6 out of 13 k-rank group(s)
# average quarterback score: 0.043208705622787294
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'Jos.Allen']
#
#
# Receivers: ['J.Witten', 'L.Vickers', 'J.Holley', 'D.Bryant', 'J.Hanna', 'T.Williams', 'G.Escobar', 'J.Randle', 'L.Dunbar', 'C.Washington']
#
#
#
# GROUP 7 out of 13 k-rank group(s)
# average quarterback score: 0.08290801931347126
# -------------------------------------
#
# Quarterbacks['T.Heinicke', 'T.Bridgewater', 'M.Jones', 'P.Walker']
#
#
# Receivers: ['B.Bersin', 'C.Brown', 'C.Artis-Payne', 'B.Hartsock', 'D.Reaves', 'K.Pilares', 'I.Zuber', 'R.Brockel', 'J.Adams', 'D.Asiasi']
#
#
#
# GROUP 8 out of 13 k-rank group(s)
# average quarterback score: 0.030301965585223165
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'D.Williams', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis', 'D.Adams']
#
#
#
# GROUP 9 out of 13 k-rank group(s)
# average quarterback score: 0.02986358962632622
# -------------------------------------
#
# Quarterbacks['J.Herbert']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'P.Crayton', 'C.Davis', 'G.Banks', 'C.Brinkley', 'R.Goodman', 'K.Allen']
#
#
#
# GROUP 10 out of 13 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['J.Burrow']
#
#
# Receivers: ['A.Green', 'R.Whalen', 'C.Cochart', 'J.Wright', 'J.Fisher', 'T.Boyd', 'J.Mixon', 'J.Franks', 'A.Tate', 'T.Irwin']
#
#
#
# GROUP 11 out of 13 k-rank group(s)
# average quarterback score: 0.030117254411036673
# -------------------------------------
#
# Quarterbacks['M.Rudolph']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'I.Redman', 'B.Batch', 'Wi.Johnson', 'D.Moye', 'C.Rainey', 'D.Paulson', 'C.Hamilton']
#
#
#
# GROUP 12 out of 13 k-rank group(s)
# average quarterback score: 0.030273239115915562
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'A.Crumpler', 'M.Slater', 'R.Gronkowski', 'A.Hernandez', 'N.Solder', 'M.Williams', 'J.Boyce', 'A.Dobson']
#
#
#
# GROUP 13 out of 13 k-rank group(s)
# average quarterback score: 0.18803518261363095
# -------------------------------------
#
# Quarterbacks['Ty.Taylor', 'C.McCoy', 'D.Carr', 'K.Cousins', 'D.Jones', 'B.Mayfield', 'P.Mahomes', 'M.White', 'J.Hurts']
#
#
# Receivers: ['R.Mundy', 'C.Daniel', 'C.McCoy', 'C.Chekwa', 'K.Hunter', 'A.Sherman', 'R.Wilson', 'N.Foles', 'S.Ware', 'T.Kelce']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 14
# GROUP 1 out of 14 k-rank group(s)
# average quarterback score: 0.0
# -------------------------------------
#
# Quarterbacks[]
#
#
# Receivers: ['H.Evans', 'D.Brees', 'L.Betts', 'J.Jones', 'D.Henderson', 'T.Humphrey', 'D.Thomas', 'M.Colston', 'A.Arrington', 'M.Ingram II']
#
#
#
# GROUP 2 out of 14 k-rank group(s)
# average quarterback score: 0.030299729076263045
# -------------------------------------
#
# Quarterbacks['R.Wilson']
#
#
# Receivers: ['C.Martin', 'D.Baldwin', 'C.Helfet', 'B.Daniels', 'K.Norwood', 'G.Farmer', 'T.Rawls', 'T.Lockett', 'G.Fant', 'T.Madden']
#
#
#
# GROUP 3 out of 14 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'G.Johnson', 'M.Johnson', 'Dr.Davis']
#
#
#
# GROUP 4 out of 14 k-rank group(s)
# average quarterback score: 0.04657354053235916
# -------------------------------------
#
# Quarterbacks['J.Brissett', 'T.Siemian']
#
#
# Receivers: ['R.Wayne', 'A.Castonzo', 'D.Carter', 'K.Adams', 'V.Ballard', 'L.Brazill', 'D.Rogers', 'J.Cunningham', 'E.Swoope', 'T.Varga']
#
#
#
# GROUP 5 out of 14 k-rank group(s)
# average quarterback score: 0.0460059086732467
# -------------------------------------
#
# Quarterbacks['T.Lawrence', 'M.Stafford']
#
#
# Receivers: ['W.Heller', 'N.Burleson', 'C.Johnson', 'S.Logan', 'J.Bell', 'T.Young', 'M.Leshoure', 'R.Broyles', 'P.Edwards', 'J.Fauria']
#
#
#
# GROUP 6 out of 14 k-rank group(s)
# average quarterback score: 0.0439993205327912
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'Jos.Allen']
#
#
# Receivers: ['J.Witten', 'L.Vickers', 'J.Holley', 'D.Bryant', 'J.Hanna', 'T.Williams', 'G.Escobar', 'J.Randle', 'L.Dunbar', 'P.Tanner']
#
#
#
# GROUP 7 out of 14 k-rank group(s)
# average quarterback score: 0.084619460912657
# -------------------------------------
#
# Quarterbacks['T.Heinicke', 'T.Bridgewater', 'M.Jones', 'P.Walker']
#
#
# Receivers: ['B.Hartsock', 'R.Brockel', 'K.Pilares', 'J.Adams', 'B.Bersin', 'C.Brown', 'D.Reaves', 'C.Artis-Payne', 'D.Funchess', 'I.Zuber']
#
#
#
# GROUP 8 out of 14 k-rank group(s)
# average quarterback score: 0.030302005481289793
# -------------------------------------
#
# Quarterbacks['Aa.Rodgers']
#
#
# Receivers: ['D.Driver', 'K.Hall', 'J.Finley', 'J.Starks', 'D.Williams', 'J.Franklin', 'K.Dorsey', 'J.Perillo', 'J.Janis', 'D.Adams']
#
#
#
# GROUP 9 out of 14 k-rank group(s)
# average quarterback score: 0.02987883127225606
# -------------------------------------
#
# Quarterbacks['J.Herbert']
#
#
# Receivers: ['R.McMichael', 'A.Gates', 'K.Washington', 'M.Floyd', 'P.Crayton', 'C.Davis', 'G.Banks', 'C.Brinkley', 'R.Goodman', 'K.Allen']
#
#
#
# GROUP 10 out of 14 k-rank group(s)
# average quarterback score: 0.030303030303030304
# -------------------------------------
#
# Quarterbacks['J.Burrow']
#
#
# Receivers: ['A.Green', 'R.Whalen', 'C.Cochart', 'J.Wright', 'J.Fisher', 'T.Boyd', 'J.Mixon', 'J.Franks', 'A.Tate', 'T.Irwin']
#
#
#
# GROUP 11 out of 14 k-rank group(s)
# average quarterback score: 0.030120253426883004
# -------------------------------------
#
# Quarterbacks['M.Rudolph']
#
#
# Receivers: ['H.Ward', 'A.Randle El', 'H.Miller', 'I.Redman', 'B.Batch', 'Wi.Johnson', 'D.Moye', 'C.Rainey', 'D.Paulson', 'C.Hamilton']
#
#
#
# GROUP 12 out of 14 k-rank group(s)
# average quarterback score: 0.030281582794153702
# -------------------------------------
#
# Quarterbacks['T.Brady']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'A.Crumpler', 'D.Branch', 'M.Slater', 'R.Gronkowski', 'A.Hernandez', 'N.Solder', 'M.Williams', 'J.Boyce']
#
#
#
# GROUP 13 out of 14 k-rank group(s)
# average quarterback score: 0.04955238774093812
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'D.Jones']
#
#
# Receivers: ['M.Clayton', 'B.Jacobs', 'M.Hedgecock', 'D.Thomas', 'R.Barden', 'T.Beckum', 'A.Brown', 'D.Calhoun', 'V.Cruz', 'J.Jernigan']
#
#
#
# GROUP 14 out of 14 k-rank group(s)
# average quarterback score: 0.04781437414714823
# -------------------------------------
#
# Quarterbacks['D.Carr', 'P.Mahomes']
#
#
# Receivers: ['R.Mundy', 'C.Daniel', 'C.McCoy', 'C.Chekwa', 'R.Wilson', 'T.Kelce', 'M.Barkley', 'E.Fisher', 'A.Villanueva', 'G.Gilliam']
#
#
#
#
# --------------------------------------------------------------------------------

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(k_ranks, avg_qb_scores)
plt.xlabel('k (k-rank NMF)')
plt.ylabel('Average QB Score')
plt.title(f'Average QB Score vs. k (alpha=0,tolerance=0.01) ({time_period[0]}-{time_period[-1]})')
plt.show()

# %%
k_ranks = np.arange(3,15)  # The number of "receiver groups" to learn
tolerance = 0.01 # Stopping condition for training. Smaller value = more training

alpha_vals = np.arange(0, 1, 0.01)
avg_qb_scores = []


for alpha in alpha_vals:
    k=3
    print(f'K = {k}')

    model = NMF(n_components=3, init='random', tol=tolerance, 
                random_state=0, 
                alpha_W=alpha, 
                alpha_H=alpha)

    W = model.fit_transform(X)
    H = model.components_

    # --------------------------------------------------------------------------------

    # creating the dataframe
    df_X = pd.DataFrame(data = X, 
                      index = list(receiver_df.player_name), 
                      columns = list(passer_df.player_name))
    # df_X

    # normalizing our learned matrices for analysis

    H_row_sum = np.sum(H, axis=0).reshape(1,-1)
    H_norm = np.divide(H, H_row_sum, out=np.zeros_like(H), where=H_row_sum!=0)

    df_H = pd.DataFrame(data = H_norm, 
                      index = [f'rec_group_{n}' for n in range(H_norm.shape[0])], 
                      columns = list(passer_df.player_name))
    # df_H


    W_col_sum = np.sum(W, axis=1).reshape(-1,1)
    W_norm = np.divide(W, W_col_sum, out=np.zeros_like(W), where=W_col_sum!=0)


    df_W = pd.DataFrame(data = W_norm, 
                      index = list(receiver_df.player_name), 
                      columns = [f'rec_group_{n}' for n in range(W_norm.shape[1])])
    # df_W

    # --------------------------------------------------------------------------------

    group_qb_scores = []
    
    for group in range(k):
        
        
        print(f'GROUP {group+1} out of {k} k-rank group(s)')

        qb_rankings = df_H.loc[f'rec_group_{group}'].where(df_H.loc[f'rec_group_{group}'] > .5).dropna()

        avg_qb_score = 0 

        for qb in qb_rankings.index:
            if (qb in nfl_qbs):
                avg_qb_score += qb_rankings.loc[qb]
    #             print(f'{qb}: {qb_rankings.loc[qb]}')

        avg_qb_score /= len(nfl_qbs)
        group_qb_scores.append(avg_qb_score)

        print(f'average quarterback score: {avg_qb_score}')
        
        print('-------------------------------------\n')
        # All quarterbacks are ranked (qb_rankings), this line takes only those starting in the 2021 season (nfl_qbs)
        print(f'Quarterbacks{list(set(qb_rankings.index) & set(nfl_qbs))}')
        print('\n')
        print(f'Receivers: {list(df_W.nlargest(10,f"rec_group_{group}").iloc[:10].T.columns)}')
    #     display(df_W.nlargest(25,f'rec_group_{group}').iloc[:25].T)
        print('\n\n')
        
    avg_qb_scores.append(np.mean(group_qb_scores))

    print('\n--------------------------------------------------------------------------------\n')
# Out:
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2337441615971024
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.35409851552807786
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Goff', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07181846311613063
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.24994469160502836
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33771044538685285
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0715370606798256
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2506122144503504
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33779002455549373
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07125406858963129
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2506869619245316
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.35479509716472957
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Goff', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07096000225193562
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2528550745308751
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33318163280170937
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07076985540078959
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25278705874537677
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3352082432409823
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.07050689176089636
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25474344412494754
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3290785657713393
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0703271969694798
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25473185100607293
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3307065460127142
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0700980492811876
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25467683180403744
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33230802296206763
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06988300139351232
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25674720050054395
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3254378903320821
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06974874483403867
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2567978186547527
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.32654267483016536
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06956894762843371
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield', 'R.Tannehill']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25679969373280964
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3277007044472156
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05432820252630846
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2740353991071913
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3061542629931411
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.054298282408463204
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27386357680694146
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.30744083092456126
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.054234527717888885
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27353815926232167
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.32419246165637267
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05417153780596316
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.25808071265168975
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3260512378550049
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'P.Mahomes', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05411042161223935
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2751374038237961
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3054337016809403
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05408925530546364
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2746000476749142
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3073586445105211
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05403345523743846
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27639069271970723
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2731580462561229
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05401503710810654
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27587826800463855
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2741905230690841
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05396589581229086
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27526651660510315
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3061877813877198
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'D.Jones', 'J.Fields', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05391706607329171
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2767920073201559
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2730848004016376
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05390361412145939
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2757684141984507
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.27483049843527685
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05385158586595613
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2768638977998699
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.27318706922528574
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05383573347003738
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2753802425603337
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.27558125967600094
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0537782389842736
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27592538007651657
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.27475495858140353
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053756859997110704
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2759277371748885
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2747299974469165
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05372677914856849
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27733320656739485
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2579884343614696
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05372272816460344
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27718245979167033
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2584441240512336
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05368859002818638
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2766979293051473
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.25908995971077226
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053658183364610215
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27641924525081896
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2593998308469998
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053640971487977425
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.276112642609427
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2597303905863262
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05362411280185014
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2757541893810877
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.26010725326016
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'M.Lewis', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053606904514166664
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3079978141157493
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'K.Cousins', 'T.Heinicke', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.25841308475078184
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053634083339087556
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.29228445435453676
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.25882071831215586
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05361836046409875
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2767951340671386
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2591554738094949
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05360485960145592
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27645016124361893
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.259517549480642
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.053591139298055354
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27604873929862445
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.25993190050394593
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'J.Herbert', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'D.Carr', 'J.Fields', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'R.Grant', 'J.Kuhn', 'B.Jackson', 'Ja.Jones', 'K.Hall', 'J.Nelson', 'J.Finley', 'B.Swain', 'T.Crabtree']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05357654471602331
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy', 'C.Daniel']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.30853103128780085
# -------------------------------------
#
# Quarterbacks['T.Siemian', 'J.Goff', 'Jos.Allen', 'M.Jones', 'J.Garoppolo', 'Ty.Taylor', 'M.Rudolph', 'T.Brady', 'D.Carr', 'J.Brissett', 'K.Cousins', 'T.Heinicke', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'H.Ward', 'S.Morris', 'A.Crumpler', 'C.Ochocinco', 'D.Stallworth', 'A.Randle El', 'D.Branch', 'B.Lloyd']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2581888097553346
# -------------------------------------
#
# ...
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190125709753046
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3760266836273601
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.241024774507083
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190206297400136
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37625629413529454
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24091795395435267
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190292847167778
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3764833135285119
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24081201041810138
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190384384802583
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37670846428564186
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24070668131103856
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051904806963316036
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37692602075816495
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24060482088635085
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190578615268204
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37508462212951676
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.2416468015354979
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051906044340627046
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3753051229862603
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24154428203000372
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190706892645831
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3755402852310809
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24143522182283403
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0519082193032671
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37577609726229755
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24132741327747914
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05190947122592077
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37601085228001285
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24121991895964573
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05191076999056363
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37624156233520845
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24111402038056104
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051912097301948665
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.37647810511884505
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'L.Jackson', 'C.McCoy', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill', 'J.Hurts']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.24100554002072672
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05191351786504449
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(alpha_vals, avg_qb_scores)
plt.xlabel('alpha')
plt.ylabel('Average QB Score')
plt.title(f'Average QB Score vs. alpha (k=3, tolerance=0.01) ({time_period[0]}-{time_period[-1]})')
plt.show()

# %%
tolerances = np.arange(0.0001, 0.01, 0.0001) # Stopping condition for training. Smaller value = more training

alpha = 0.5
avg_qb_scores = []


for tol in tolerances:
    k=3
    print(f'K = {k}')

    model = NMF(n_components=3, init='random', tol=tol, 
                random_state=0, 
                alpha_W=alpha, 
                alpha_H=alpha)

    W = model.fit_transform(X)
    H = model.components_

    # --------------------------------------------------------------------------------

    # creating the dataframe
    df_X = pd.DataFrame(data = X, 
                      index = list(receiver_df.player_name), 
                      columns = list(passer_df.player_name))
    # df_X

    # normalizing our learned matrices for analysis

    H_row_sum = np.sum(H, axis=0).reshape(1,-1)
    H_norm = np.divide(H, H_row_sum, out=np.zeros_like(H), where=H_row_sum!=0)

    df_H = pd.DataFrame(data = H_norm, 
                      index = [f'rec_group_{n}' for n in range(H_norm.shape[0])], 
                      columns = list(passer_df.player_name))
    # df_H


    W_col_sum = np.sum(W, axis=1).reshape(-1,1)
    W_norm = np.divide(W, W_col_sum, out=np.zeros_like(W), where=W_col_sum!=0)

    df_W = pd.DataFrame(data = W_norm, 
                      index = list(receiver_df.player_name), 
                      columns = [f'rec_group_{n}' for n in range(W_norm.shape[1])])
    # df_W

    # --------------------------------------------------------------------------------

    group_qb_scores = []
    
    for group in range(k):
        
        
        print(f'GROUP {group+1} out of {k} k-rank group(s)')

        qb_rankings = df_H.loc[f'rec_group_{group}'].where(df_H.loc[f'rec_group_{group}'] > .5).dropna()

        avg_qb_score = 0 

        for qb in qb_rankings.index:
            if (qb in nfl_qbs):
                avg_qb_score += qb_rankings.loc[qb]
    #             print(f'{qb}: {qb_rankings.loc[qb]}')

        avg_qb_score /= len(nfl_qbs)
        group_qb_scores.append(avg_qb_score)

        print(f'average quarterback score: {avg_qb_score}')
        
        print('-------------------------------------\n')
        # All quarterbacks are ranked (qb_rankings), this line takes only those starting in the 2021 season (nfl_qbs)
        print(f'Quarterbacks{list(set(qb_rankings.index) & set(nfl_qbs))}')
        print('\n')
        print(f'Receivers: {list(df_W.nlargest(10,f"rec_group_{group}").iloc[:10].T.columns)}')
    #     display(df_W.nlargest(25,f'rec_group_{group}').iloc[:25].T)
        print('\n\n')
        
    avg_qb_scores.append(np.mean(group_qb_scores))

    print('\n--------------------------------------------------------------------------------\n')
# Out:
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.258221432535555
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'M.Rudolph', 'Aa.Rodgers', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'H.Miller', 'M.Spaeth', 'R.Mendenhall', 'I.Redman', 'D.Johnson', 'J.Dwyer']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.382297822735976
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'R.Wilson', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06810793746147596
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2594401782403046
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'M.Rudolph', 'Aa.Rodgers', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.36617699407070287
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06803442036264287
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2605529193681916
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'M.Rudolph', 'Aa.Rodgers', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.36525413818370195
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.067963259829437
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2767933978204479
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.36432302486597745
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0678915688748491
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.27806713323354876
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3634367198324039
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06782339289013466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2792917399909857
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3625469468643887
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06775511202996047
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2803827774935465
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.36171925179398334
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06769178023094498
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.28158294972457953
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.36077380958332517
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06761965686855693
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2825572610522963
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3599782916203069
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06755918015031921
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'L.Jackson', 'M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2835965088491718
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.359100690409981
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06749273214692128
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'L.Jackson', 'M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.28432542039320297
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3584663973511671
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06744488615743596
# -------------------------------------
#
# Quarterbacks['B.Mayfield', 'L.Jackson', 'M.Ryan']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'M.Cox']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2854689016875275
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.35743492023104706
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'C.Wentz', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'P.Walker', 'J.Burrow', 'M.Stafford', 'J.Hurts']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06736743732915684
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2862664720322005
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3416369440992234
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06731182552821735
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2870930349754152
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3409762100558975
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06725284182419278
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.28751717067552723
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.340629125789623
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06722203091186266
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.288387136969426
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33989926603203807
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06715765222449835
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.28883299669256235
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3395152230834221
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.06712402524990585
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'L.Jackson', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2897465108189978
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3387063217223547
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051937745270529356
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.29021422019681836
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'K.Hall']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3382806921245127
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193718034309999
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2906893079932393
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33784012748497594
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193669299810436
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2911718668839276
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33738399160441707
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051936293610836064
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.29166207487552126
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33691165104221366
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193599321639374
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Jenkins', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.29216009707457513
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33642249308934963
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193580211967395
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2926661369732977
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33591598351561547
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0519357310830489
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.2931804333702335
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.335391741320475
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051935791115627974
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3089169657421898
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3348496511103504
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.0519359926503435
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.30956341942084364
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31914579819850253
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193634460498089
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3102228962662293
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31857755678502975
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193685447446384
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3102228962662293
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31857755678502975
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193685447446384
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3108957334985378
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31799021199392447
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051937530546897905
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3108957334985378
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31799021199392447
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051937530546897905
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31158204566097286
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3173853363734676
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193839177571574
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31158204566097286
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.3173853363734676
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193839177571574
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31228185634869526
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31676610703457675
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193945396113284
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31228185634869526
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31676610703457675
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193945396113284
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3129950568798009
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33131685804305316
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051940661396104246
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.3129950568798009
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.33131685804305316
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'C.McCoy', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051940661396104246
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# ...
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski', 'A.Hernandez']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.051942983366028254
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'J.Snelling', 'H.Douglas', 'R.Mundy']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------
#
# K = 3
# GROUP 1 out of 3 k-rank group(s)
# average quarterback score: 0.31827974483768234
# -------------------------------------
#
# Quarterbacks['D.Prescott', 'T.Siemian', 'Jos.Allen', 'C.Wentz', 'T.Bridgewater', 'R.Wilson', 'Aa.Rodgers', 'M.Rudolph', 'D.Carr', 'J.Fields', 'P.Mahomes', 'M.White', 'R.Tannehill']
#
#
# Receivers: ['D.Driver', 'H.Ward', 'P.Burress', 'A.Randle El', 'M.Moore', 'R.Grant', 'H.Miller', 'B.Jackson', 'M.Spaeth', 'Ja.Jones']
#
#
#
# GROUP 2 out of 3 k-rank group(s)
# average quarterback score: 0.31674599789725616
# -------------------------------------
#
# Quarterbacks['J.Goff', 'M.Jones', 'J.Hurts', 'J.Garoppolo', 'T.Lawrence', 'J.Herbert', 'Ty.Taylor', 'T.Brady', 'D.Carr', 'J.Brissett', 'D.Jones', 'T.Heinicke', 'J.Burrow', 'M.Stafford', 'P.Walker']
#
#
# Receivers: ['K.Faulk', 'F.Taylor', 'S.Morris', 'T.Brady', 'A.Crumpler', 'D.Branch', 'B.Lloyd', 'M.Slater', 'J.Edelman', 'R.Gronkowski']
#
#
#
# GROUP 3 out of 3 k-rank group(s)
# average quarterback score: 0.05193787532657466
# -------------------------------------
#
# Quarterbacks['M.Ryan', 'B.Mayfield']
#
#
# Receivers: ['B.Finneran', 'T.Gonzalez', 'J.Peelle', 'O.Mughelli', 'M.Turner', 'R.White', 'J.Norwood', 'E.Weems', 'J.Snelling', 'H.Douglas']
#
#
#
#
# --------------------------------------------------------------------------------

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(tolerances, avg_qb_scores)
plt.xlabel('tolerance')
plt.ylabel('Average QB Score')
plt.title(f'Average QB Score vs. tolerance (k=3, alpha=0.5) ({time_period[0]}-{time_period[-1]})')
plt.show()
